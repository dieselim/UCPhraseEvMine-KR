# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)  # 열의 너비 제한 없애기

# %%
import subprocess
import os

path = '/home/dieselim/KISDI/UCPhrase/src_klue_mecab'

# Change the directory to 'src'
os.chdir(path)

# Execute the python script with arguments
subprocess.run(['python', 'step2.py', '--gpu', 'True', '--dir_data', '../data/news'], stdout=None, stderr=None, text=True)
# Out:
# ARGS: {'gpu': 'True', 'dir_data': '../data/news', 'exp_prefix': '', 'model_prefix': '', 'path_model_config': '../configs/core.CNN.3layers.json'}
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [consts] Loading pretrained model: klue/roberta-base OK!
# Traceback (most recent call last):
#   File "/home/dieselim/miniconda3/lib/python3.12/site-packages/MeCab/__init__.py", line 137, in __init__
#     super(Tagger, self).__init__(args)
# RuntimeError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/dieselim/miniconda3/lib/python3.12/site-packages/konlpy/tag/_mecab.py", line 77, in __init__
#     self.tagger = Tagger('-d %s' % dicpath)
# ...

# %%
from konlpy.tag import Mecab

tagger = Mecab('/home/dieselim/.local/lib/mecab/dic/mecab-ko-dic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/konlpy/tag/_mecab.py:77, in Mecab.__init__(self, dicpath)
#      76 try:
# ---> 77     self.tagger = Tagger('-d %s' % dicpath)
#      78     self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# NameError: name 'Tagger' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 from konlpy.tag import Mecab
# ----> 3 tagger = Mecab('/home/dieselim/.local/lib/mecab/dic/mecab-ko-dic')
#
# File ~/miniconda3/lib/python3.12/site-packages/konlpy/tag/_mecab.py:82, in Mecab.__init__(self, dicpath)
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle

# .pk 파일 경로
file_path = '/Users/im-yukyung/Desktop/KISDI/240603/UCPhrase-exp-master/experiments/sample-kobert-base-v1-core.CNN.3layers_mecab/model/final.predict.epoch-19/tokenized.id.sample.pk'

# 파일을 읽기 모드로 열기
with open(file_path, 'rb') as file:
    # 파일 내용을 역직렬화하여 객체로 로드
    data = pickle.load(file)

# 로드된 데이터 확인
#print(data)
data[0]
# Out:
# {'_id_': '020c0c7c03a409dd25e82fc6a82638fd',
#  'sents': [{'spans': [(0, 5, 0.3918372),
#     (1, 7, 0.09679201),
#     (3, 8, 0.07616869),
#     (4, 9, 0.12787831),
#     (5, 10, 0.03470185),
#     (6, 11, 0.05110102),
#     (8, 12, 0.012552661),
#     (9, 14, 0.008959243),
#     (10, 15, 0.016026275),
#     (0, 4, 0.6743547),
#     (1, 5, 0.28858843),
#     (3, 7, 0.08504129),
#     (4, 8, 0.28410426),
#     (5, 9, 0.08585527),
#     (6, 10, 0.22280537),
#     (8, 11, 0.016016766),
#     (9, 12, 0.04945319),
#     (10, 14, 0.043477513),
#     (11, 15, 0.17577188),
#     (0, 3, 0.8544942),
#     (1, 4, 0.56110364),
#     (3, 5, 0.3154874),
#     (4, 7, 0.2839946),
#     (5, 8, 0.2490767),
#     (6, 9, 0.39893398),
#     (8, 10, 0.12982522),
#     (9, 11, 0.0693446),
#     (10, 12, 0.2943749),
#     (11, 14, 0.34600055),
#     (12, 15, 0.06339462),
#     (0, 2, 0.80672055),
#     (1, 3, 0.8285096),
#     (3, 4, 0.70882154),
#     (4, 5, 0.7840257),
#     (5, 7, 0.33439556),
# ...

# %%
import pickle

# .pk 파일 경로
file_path = '/Users/im-yukyung/Desktop/KISDI/240603/UCPhrase-exp-master/experiments/sample-kobert-base-v1-core.CNN.3layers/model/final.predict.epoch-14/tokenized.id.output_data.pk'

# 파일을 읽기 모드로 열기
with open(file_path, 'rb') as file:
    # 파일 내용을 역직렬화하여 객체로 로드
    data = pickle.load(file)

# 로드된 데이터 확인
#print(data)
data[0]
# Out:
# {'_id_': '00005f0382f676b0f4910f1cfbd831a5',
#  'sents': [{'spans': [(16, 25, 0.10809049),
#     (18, 27, 0.08973429),
#     (12, 20, 0.11026999),
#     (16, 23, 0.1718884),
#     (18, 25, 0.13993494),
#     (20, 27, 0.1372704),
#     (0, 8, 0.09425324),
#     (2, 11, 0.08983967),
#     (9, 17, 0.11362132),
#     (12, 19, 0.15676272),
#     (16, 20, 0.5271916),
#     (18, 23, 0.36524683),
#     (20, 25, 0.3738001),
#     (21, 27, 0.22353083),
#     (0, 2, 0.7038628),
#     (2, 8, 0.22153667),
#     (3, 11, 0.10712554),
#     (9, 15, 0.22204754),
#     (12, 17, 0.38975906),
#     (16, 19, 0.64934844),
#     (18, 20, 0.69735014),
#     (20, 23, 0.6198773),
#     (21, 25, 0.5305122),
#     (24, 27, 0.6343446),
#     (26, 34, 0.09194819),
#     (35, 41, 0.14464003)],
#    'ids': [1644,
#     7095,
#     2209,
#     3533,
#     7688,
#     18,
#     7040,
#     7706,
#     40,
#     2714,
#     6879,
#     7119,
#     1233,
#     7040,
#     7706,
#     6665,
#     1741,
#     7268,
# ...
